# %%
import pandas as pd
import numpy as np
from numpy import array
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the Dataset

# %%
raw_dataset = pd.read_csv('./station_rio.csv', index_col='YEAR')
extra_variables = raw_dataset.iloc[:,12:]
raw_dataset = raw_dataset.iloc[:,:12]

# %%
raw_dataset.head()
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 1973  27.73  27.97  25.70  26.49  22.42  22.76  22.14  21.03  21.46  22.46
# 1974  26.68  27.16  26.56  23.94  22.76  20.70  21.20  21.81  22.91  22.80
# 1975  25.27  26.92  26.43  22.82  21.37  20.50  19.68  22.98  22.40  22.65
# 1976  27.48  26.20  25.55  24.99  22.01  21.18  20.14  21.15  21.27  22.06
# 1977  27.13  28.51  26.88  24.22  22.35  22.13  23.07  22.29  22.44  23.92
#
#         NOV    DEC
# YEAR
# 1973  23.06  25.85
# 1974  24.51  24.54
# 1975  24.11  26.53
# 1976  24.40  25.56
# 1977  24.48  24.84

# %%
raw_dataset.tail()
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 2015  29.93  28.43  26.78  25.93  23.18  21.98  22.93  23.53  23.28  25.33
# 2016  27.08  28.98  27.43  27.93  22.93  20.53  21.53  23.23  23.03  24.48
# 2017  28.92  28.27  26.97  25.52  22.57  21.97  20.02  22.42  24.22  25.97
# 2018  28.06  27.21  27.81  26.26  23.81  22.91  22.96  21.91  23.71  24.56
# 2019  30.25  28.05  27.50  26.55  24.85  23.10  21.75  22.30  23.05  25.25
#
#          NOV     DEC
# YEAR
# 2015   26.43  999.90
# 2016   24.78   27.22
# 2017   25.47   27.01
# 2018   25.61   27.55
# 2019  999.90  999.90

# %%
extra_variables.head()
# Out:
#       D-J-F  M-A-M  J-J-A  S-O-N  metANN
# YEAR
# 1973  27.45  24.87  21.98  22.33   24.16
# 1974  26.56  24.42  21.24  23.41   23.91
# 1975  25.58  23.54  21.05  23.05   23.31
# 1976  26.74  24.18  20.82  22.58   23.58
# 1977  27.07  24.48  22.50  23.61   24.42

# %% [markdown]
# ### Data Preprocessing

# %%
def split_dataset(data):
    # split into standard weeks
    train, test = data[:-34], data[-34:]
    # restructure into windows of weekly data
    train = np.array(np.split(train, len(train)/17))
    test = np.array(np.split(test, len(test)/17))
    return train, test

def to_supervised(train, n_input, n_out):
    # flatten data
    data = train.reshape((train.shape[0]*train.shape[1], train.shape[2]))
    X, y = list(), list()
    in_start = 0
    # step over the entire history one time step at a time
    for _ in range(len(data)):
        # define the end of the input sequence
        in_end = in_start + n_input
        out_end = in_end + n_out
        # ensure we have enough data for this instance
        if out_end < len(data):
            x_input = data[in_start:in_end, 0]
            x_input = x_input.reshape((len(x_input), 1))
            X.append(x_input)
            y.append(data[in_end:out_end, 0])
        # move along one time step
        in_start += 1
    return array(X), array(y)

# %%
series_to_plot = []

for year in range(len(raw_dataset.values)):
    for month in raw_dataset.values[year]:
        series_to_plot.append(month)

# Handling wrong values
for i in range(len(series_to_plot)):
    if series_to_plot[i] > 60:
        num1 = 0
        num2 = 0
        
        k = 0
        while series_to_plot[k] > 60:
            k = k+1
        num1 = series_to_plot[k]
        
        k = 0
        while series_to_plot[k] > 60:
            k = k-1
        num2 = series_to_plot[k]
        
        series_to_plot[i] = (num1 + num2)/2
        
plt.figure(figsize=(16, 5))
plt.plot(series_to_plot, label='Mean Temperature')
plt.title('Temperature over time')
plt.show()

# %%
series = []

#Turning dataset into a serie
for year in range(len(raw_dataset.values)):
    for month in raw_dataset.values[year]:
        series.append(month)
    for var in extra_variables.values[year]:
        series.append(var)

# Handling wrong values
for i in range(len(series)):
    if series[i] > 60:
        num1 = 0
        num2 = 0
        
        k = 0
        while series[k] > 60:
            k = k+1
        num1 = series[k]
        
        k = 0
        while series[k] > 60:
            k = k-1
        num2 = series[k]
        
        series[i] = (num1 + num2)/2


series = np.array(series)
series.shape = (series.shape[0],1)
train, test = split_dataset(series)

n_input=17
train_x, train_y = to_supervised(train, n_input, 12)
test_x, test_y = to_supervised(train, n_input, 12)

print(train_x[0].flatten())
print(train_y[0])
print('-------------------------------------------------------------------------')
print(train_x[1].flatten())
print(train_y[1])
# Out:
# [27.73 27.97 25.7  26.49 22.42 22.76 22.14 21.03 21.46 22.46 23.06 25.85
#  27.45 24.87 21.98 22.33 24.16]
# [26.68 27.16 26.56 23.94 22.76 20.7  21.2  21.81 22.91 22.8  24.51 24.54]
# -------------------------------------------------------------------------
# [27.97 25.7  26.49 22.42 22.76 22.14 21.03 21.46 22.46 23.06 25.85 27.45
#  24.87 21.98 22.33 24.16 26.68]
# [27.16 26.56 23.94 22.76 20.7  21.2  21.81 22.91 22.8  24.51 24.54 26.56]

# %% [markdown]
# ### Definition of the Model

# %%
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout , LSTM , Bidirectional 

# define parameters
verbose, epochs, batch_size = 1, 70, 20
n_timesteps, n_features, n_outputs = train_x.shape[1], train_x.shape[2], train_y.shape[1]

# define model
model = Sequential()
model.add(Bidirectional(LSTM(200, activation='relu', input_shape=(n_timesteps, n_features), return_sequences=True)))
model.add(Dense(200, activation='relu'))
model.add(Bidirectional(LSTM(200, activation='relu', input_shape=(n_timesteps, n_features))))
model.add(Dropout(0.2))
model.add(Dense(n_outputs))
model.compile(loss='mse', optimizer='adam')

# fit network
history = model.fit(train_x, train_y, epochs=epochs, batch_size=batch_size, verbose=verbose, validation_split=0.2)
# Out:
# Epoch 1/70
# 30/30 [==============================] - 5s 58ms/step - loss: 108.8636 - val_loss: 9.1109
# Epoch 2/70
# 30/30 [==============================] - 1s 45ms/step - loss: 22.3977 - val_loss: 6.7618
# Epoch 3/70
# 30/30 [==============================] - 1s 44ms/step - loss: 16.4257 - val_loss: 8.2766
# Epoch 4/70
# 30/30 [==============================] - 1s 44ms/step - loss: 15.0441 - val_loss: 6.1842
# Epoch 5/70
# 30/30 [==============================] - 1s 42ms/step - loss: 12.3330 - val_loss: 6.9748
# Epoch 6/70
# 30/30 [==============================] - 1s 43ms/step - loss: 11.8339 - val_loss: 5.7850
# Epoch 7/70
# 30/30 [==============================] - 1s 44ms/step - loss: 10.7628 - val_loss: 5.9853
# Epoch 8/70
# 30/30 [==============================] - 1s 43ms/step - loss: 10.3205 - val_loss: 5.4863
# Epoch 9/70
# 30/30 [==============================] - 1s 43ms/step - loss: 10.1227 - val_loss: 8.4743
# Epoch 10/70
# 30/30 [==============================] - 1s 43ms/step - loss: 10.4159 - val_loss: 6.5084
# Epoch 11/70
# 30/30 [==============================] - 1s 44ms/step - loss: 10.1032 - val_loss: 8.0854
# Epoch 12/70
# 30/30 [==============================] - 1s 43ms/step - loss: 9.9234 - val_loss: 5.1536
# Epoch 13/70
# 30/30 [==============================] - 2s 52ms/step - loss: 8.5740 - val_loss: 4.9770
# Epoch 14/70
# 30/30 [==============================] - 2s 57ms/step - loss: 9.1039 - val_loss: 5.3103
# Epoch 15/70
# 30/30 [==============================] - 2s 59ms/step - loss: 8.5323 - val_loss: 5.6040
# Epoch 16/70
# 30/30 [==============================] - 2s 57ms/step - loss: 8.4577 - val_loss: 4.8206
# Epoch 17/70
# 30/30 [==============================] - 2s 60ms/step - loss: 8.4670 - val_loss: 4.3433
# Epoch 18/70
# 30/30 [==============================] - 2s 58ms/step - loss: 7.9458 - val_loss: 5.1179
# Epoch 19/70
# 30/30 [==============================] - 2s 57ms/step - loss: 7.6107 - val_loss: 3.2233
# Epoch 20/70
# 30/30 [==============================] - 2s 58ms/step - loss: 7.1693 - val_loss: 3.2672
# Epoch 21/70
# 30/30 [==============================] - 2s 58ms/step - loss: 6.7903 - val_loss: 5.7299
# Epoch 22/70
# 30/30 [==============================] - 2s 57ms/step - loss: 7.5233 - val_loss: 3.9982
# Epoch 23/70
# 30/30 [==============================] - 2s 57ms/step - loss: 6.6117 - val_loss: 5.2713
# Epoch 24/70
# 30/30 [==============================] - 2s 57ms/step - loss: 7.2296 - val_loss: 2.6454
# Epoch 25/70
# 30/30 [==============================] - 2s 57ms/step - loss: 6.6561 - val_loss: 3.0786
# Epoch 26/70
# 30/30 [==============================] - 2s 56ms/step - loss: 6.7090 - val_loss: 2.7498
# Epoch 27/70
# 30/30 [==============================] - 2s 58ms/step - loss: 6.4116 - val_loss: 2.7581
# Epoch 28/70
# 30/30 [==============================] - 2s 61ms/step - loss: 6.2711 - val_loss: 2.4442
# Epoch 29/70
# 30/30 [==============================] - 2s 59ms/step - loss: 6.1356 - val_loss: 2.2746
# Epoch 30/70
# 30/30 [==============================] - 2s 63ms/step - loss: 5.8747 - val_loss: 2.2124
# Epoch 31/70
# 30/30 [==============================] - 2s 58ms/step - loss: 6.5603 - val_loss: 3.5798
# Epoch 32/70
# 30/30 [==============================] - 2s 62ms/step - loss: 6.4159 - val_loss: 2.4551
# Epoch 33/70
# 30/30 [==============================] - 2s 60ms/step - loss: 6.3612 - val_loss: 2.7140
# Epoch 34/70
# 30/30 [==============================] - 2s 61ms/step - loss: 5.9187 - val_loss: 2.2831
# Epoch 35/70
# 30/30 [==============================] - 2s 58ms/step - loss: 5.8465 - val_loss: 2.8448
# Epoch 36/70
# 30/30 [==============================] - 2s 57ms/step - loss: 5.7913 - val_loss: 3.2972
# Epoch 37/70
# 30/30 [==============================] - 2s 60ms/step - loss: 6.3221 - val_loss: 2.1213
# Epoch 38/70
# 30/30 [==============================] - 2s 60ms/step - loss: 5.6754 - val_loss: 2.4382
# Epoch 39/70
# 30/30 [==============================] - 2s 62ms/step - loss: 5.7654 - val_loss: 2.1202
# Epoch 40/70
# 30/30 [==============================] - 2s 59ms/step - loss: 5.2714 - val_loss: 2.0444
# Epoch 41/70
# 30/30 [==============================] - 2s 59ms/step - loss: 5.3243 - val_loss: 2.9078
# Epoch 42/70
# 30/30 [==============================] - 2s 63ms/step - loss: 5.3942 - val_loss: 2.3737
# Epoch 43/70
# 30/30 [==============================] - 2s 57ms/step - loss: 5.1880 - val_loss: 2.9236
# Epoch 44/70
# 30/30 [==============================] - 2s 62ms/step - loss: 5.3050 - val_loss: 2.1282
# Epoch 45/70
# 30/30 [==============================] - 2s 61ms/step - loss: 5.5623 - val_loss: 2.6153
# Epoch 46/70
# 30/30 [==============================] - 2s 63ms/step - loss: 5.2970 - val_loss: 2.4970
# Epoch 47/70
# 30/30 [==============================] - 2s 62ms/step - loss: 5.2384 - val_loss: 1.8386
# Epoch 48/70
# 30/30 [==============================] - 2s 65ms/step - loss: 5.2833 - val_loss: 2.0198
# Epoch 49/70
# 30/30 [==============================] - 2s 56ms/step - loss: 5.2633 - val_loss: 2.5017
# Epoch 50/70
# 30/30 [==============================] - 2s 61ms/step - loss: 4.9392 - val_loss: 2.5969
# Epoch 51/70
# 30/30 [==============================] - 2s 61ms/step - loss: 4.8970 - val_loss: 2.2142
# Epoch 52/70
# 30/30 [==============================] - 2s 56ms/step - loss: 5.1713 - val_loss: 1.7579
# Epoch 53/70
# 30/30 [==============================] - 2s 65ms/step - loss: 4.9318 - val_loss: 2.5544
# Epoch 54/70
# 30/30 [==============================] - 2s 55ms/step - loss: 5.0850 - val_loss: 1.6233
# Epoch 55/70
# 30/30 [==============================] - 2s 55ms/step - loss: 5.0559 - val_loss: 2.1559
# Epoch 56/70
# 30/30 [==============================] - 2s 63ms/step - loss: 5.1093 - val_loss: 2.1004
# Epoch 57/70
# 30/30 [==============================] - 2s 58ms/step - loss: 4.9778 - val_loss: 1.9239
# Epoch 58/70
# 30/30 [==============================] - 2s 60ms/step - loss: 4.9076 - val_loss: 2.4870
# Epoch 59/70
# 30/30 [==============================] - 2s 70ms/step - loss: 4.7534 - val_loss: 1.7287
# Epoch 60/70
# 30/30 [==============================] - 2s 66ms/step - loss: 5.1601 - val_loss: 2.1751
# Epoch 61/70
# 30/30 [==============================] - 2s 76ms/step - loss: 4.6580 - val_loss: 1.8259
# Epoch 62/70
# 30/30 [==============================] - 2s 78ms/step - loss: 4.6419 - val_loss: 3.0308
# Epoch 63/70
# 30/30 [==============================] - 2s 69ms/step - loss: 5.3522 - val_loss: 2.4909
# Epoch 64/70
# 30/30 [==============================] - 2s 61ms/step - loss: 4.7185 - val_loss: 1.7502
# Epoch 65/70
# 30/30 [==============================] - 2s 57ms/step - loss: 5.0470 - val_loss: 3.5429
# Epoch 66/70
# 30/30 [==============================] - 2s 60ms/step - loss: 5.4881 - val_loss: 2.0551
# Epoch 67/70
# 30/30 [==============================] - 2s 56ms/step - loss: 4.7933 - val_loss: 2.1151
# Epoch 68/70
# 30/30 [==============================] - 2s 56ms/step - loss: 4.5181 - val_loss: 1.9865
# Epoch 69/70
# 30/30 [==============================] - 2s 57ms/step - loss: 4.7368 - val_loss: 4.0541
# Epoch 70/70
# 30/30 [==============================] - 2s 59ms/step - loss: 4.6169 - val_loss: 1.8136

# %%
plt.plot(history.history["loss"],label="loss")
plt.plot(history.history["val_loss"],label="val_loss")
plt.legend(loc="best")
plt.xlabel("No. Of Epochs")
plt.ylabel("mse score")
plt.show()

# %% [markdown]
# ### Validation Test Forecasting

# %%
def forecast(model, history, n_input):
    # flatten data
    data = array(history)
    data = data.reshape((data.shape[0]*data.shape[1], data.shape[2]))
    input_x = data[-n_input:, 0]
#     reshape into [1, n_input, 1]
    input_x = input_x.reshape((1, len(input_x), 1))
    print(input_x.shape)
    yhat = model.predict(input_x, verbose=0)
#     we only want the vector forecast
    yhat = yhat[0]
    return yhat

history = [x for x in train]
predictions = list()

for i in range(len(test)):
    yhat_sequence = forecast(model, history, n_input)
    predictions.append(yhat_sequence)
    history.append(test[i, :])
# Out:
# (1, 17, 1)
# (1, 17, 1)

# %%
predictions = array(predictions)
y_pred = predictions.flatten()

y_test_1 = test[0,:12]
y_test_2 = test[1,:12]
y_test = np.concatenate((y_test_1,y_test_2)).flatten()

from sklearn.metrics import mean_squared_error, r2_score
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print(rmse_lstm)
# Out:
# 1.3763796835112745

# %%
plt.figure(figsize=(10, 5))
plt.plot(y_test, label='true')
plt.plot(y_pred, label='predicted')
plt.show()

# %% [markdown]
# ### Future Data Forecasting

# %%
forecast = y_pred 
forecast = np.concatenate((y_pred, model.predict(test_x[-1].reshape(1,17,1)).flatten()))

plt.figure(figsize=(10, 5))
plt.plot(y_test, label='true')
plt.plot(forecast, label='forecast')
plt.show()

# %% [markdown]
# ### Export and Save the Model

# %%
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)


# serialize weights to HDF5
model.save("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
