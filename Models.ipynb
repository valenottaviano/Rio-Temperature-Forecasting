# %%
import pandas as pd
from numpy import array
from numpy import split
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_dataset = pd.read_csv('./station_rio.csv', index_col='YEAR')
raw_dataset.head()
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 1973  27.73  27.97  25.70  26.49  22.42  22.76  22.14  21.03  21.46  22.46
# 1974  26.68  27.16  26.56  23.94  22.76  20.70  21.20  21.81  22.91  22.80
# 1975  25.27  26.92  26.43  22.82  21.37  20.50  19.68  22.98  22.40  22.65
# 1976  27.48  26.20  25.55  24.99  22.01  21.18  20.14  21.15  21.27  22.06
# 1977  27.13  28.51  26.88  24.22  22.35  22.13  23.07  22.29  22.44  23.92
#
#         NOV    DEC  D-J-F  M-A-M  J-J-A  S-O-N  metANN
# YEAR
# 1973  23.06  25.85  27.45  24.87  21.98  22.33   24.16
# 1974  24.51  24.54  26.56  24.42  21.24  23.41   23.91
# 1975  24.11  26.53  25.58  23.54  21.05  23.05   23.31
# 1976  24.40  25.56  26.74  24.18  20.82  22.58   23.58
# 1977  24.48  24.84  27.07  24.48  22.50  23.61   24.42

# %%
raw_dataset.tail()
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 2015  29.93  28.43  26.78  25.93  23.18  21.98  22.93  23.53  23.28  25.33
# 2016  27.08  28.98  27.43  27.93  22.93  20.53  21.53  23.23  23.03  24.48
# 2017  28.92  28.27  26.97  25.52  22.57  21.97  20.02  22.42  24.22  25.97
# 2018  28.06  27.21  27.81  26.26  23.81  22.91  22.96  21.91  23.71  24.56
# 2019  30.25  28.05  27.50  26.55  24.85  23.10  21.75  22.30  23.05  25.25
#
#          NOV     DEC  D-J-F  M-A-M  J-J-A  S-O-N  metANN
# YEAR
# 2015   26.43  999.90  28.91  25.30  22.81  25.01   25.51
# 2016   24.78   27.22  27.63  26.10  21.76  24.10   24.90
# 2017   25.47   27.01  28.14  25.02  21.47  25.22   24.96
# 2018   25.61   27.55  27.43  25.96  22.59  24.63   25.15
# 2019  999.90  999.90  28.62  26.30  22.38  24.74   25.51

# %% [markdown]
# ### Data preprocessing

# %%
def split_sequence (sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        #find the end of the pattern
        end_ix = i + n_steps
        #check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
series = []

for year in range(len(raw_dataset.values)):
    for month in raw_dataset.values[year]:
        series.append(month)

# Handling wrong values
for i in range(len(series)):
    if series[i] > 60:
        num1 = 0
        num2 = 0
        
        k = 0
        while series[k] > 60:
            k = k+1
        num1 = series[k]
        
        k = 0
        while series[k] > 60:
            k = k-1
        num2 = series[k]
        
        series[i] = (num1 + num2)/2
        
series_arr = array(series)
X, y = split_sequence(series_arr, 12)
X = X.reshape((X.shape[0], X.shape[1], 1))
X.shape
print(X.shape, y.shape)
# Out:
# (787, 12, 1) (787,)

# %%
plt.figure(figsize=(20,5))
sns.lineplot([x for x in range(len(series))], series_arr)
plt.show()
# Out:
# /home/winston/notebook/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Bidirectional LSTM Model

# %%
x_train, y_train = X[:-12], y[:-12]
x_test, y_test = X[-12:], y[-12:]

# %%
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout , LSTM , Bidirectional 

model = Sequential()
model.add(Bidirectional(LSTM(100,return_sequences=True,input_shape=(x_train.shape[1],x_train.shape[2]))))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(100,input_shape=(x_train.shape[1],x_train.shape[2]))))
model.add(Dense(units=1))

model.compile(optimizer="adam",loss="mse")

history = model.fit(x_train, y_train, epochs=50, batch_size=12, validation_split=0.2, shuffle=True)
# Out:
# Epoch 1/50
# 52/52 [==============================] - 7s 34ms/step - loss: 123.2746 - val_loss: 7.9688
# Epoch 2/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.8562 - val_loss: 5.6329
# Epoch 3/50
# 52/52 [==============================] - 1s 16ms/step - loss: 5.6380 - val_loss: 5.6405
# Epoch 4/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6402 - val_loss: 5.7837
# Epoch 5/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6722 - val_loss: 5.7395
# Epoch 6/50
# 52/52 [==============================] - 1s 14ms/step - loss: 5.6516 - val_loss: 5.6584
# Epoch 7/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6722 - val_loss: 5.6254
# Epoch 8/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6921 - val_loss: 5.6865
# Epoch 9/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6360 - val_loss: 5.8176
# Epoch 10/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6852 - val_loss: 5.7787
# Epoch 11/50
# 52/52 [==============================] - 1s 16ms/step - loss: 5.6577 - val_loss: 5.7034
# Epoch 12/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6595 - val_loss: 5.6464
# Epoch 13/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6550 - val_loss: 5.6731
# Epoch 14/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6473 - val_loss: 5.7846
# Epoch 15/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6777 - val_loss: 5.8138
# Epoch 16/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6418 - val_loss: 5.6161
# Epoch 17/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6487 - val_loss: 5.6380
# Epoch 18/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6144 - val_loss: 5.8861
# Epoch 19/50
# 52/52 [==============================] - 1s 16ms/step - loss: 5.7085 - val_loss: 5.7500
# Epoch 20/50
# 52/52 [==============================] - 1s 15ms/step - loss: 5.6265 - val_loss: 5.6824
# Epoch 21/50
# 52/52 [==============================] - 1s 17ms/step - loss: 5.6956 - val_loss: 5.6095
# Epoch 22/50
# 52/52 [==============================] - 1s 19ms/step - loss: 5.6415 - val_loss: 5.5886
# Epoch 23/50
# 52/52 [==============================] - 1s 19ms/step - loss: 5.5576 - val_loss: 5.3912
# Epoch 24/50
# 52/52 [==============================] - 1s 18ms/step - loss: 5.1709 - val_loss: 4.9371
# Epoch 25/50
# 52/52 [==============================] - 1s 19ms/step - loss: 4.3895 - val_loss: 4.9452
# Epoch 26/50
# 52/52 [==============================] - 1s 18ms/step - loss: 3.7471 - val_loss: 3.6799
# Epoch 27/50
# 52/52 [==============================] - 1s 18ms/step - loss: 3.1336 - val_loss: 2.8537
# Epoch 28/50
# 52/52 [==============================] - 1s 19ms/step - loss: 3.0037 - val_loss: 3.0603
# Epoch 29/50
# 52/52 [==============================] - 1s 19ms/step - loss: 2.8102 - val_loss: 2.8532
# Epoch 30/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.7670 - val_loss: 2.4969
# Epoch 31/50
# 52/52 [==============================] - 1s 19ms/step - loss: 2.5429 - val_loss: 2.5315
# Epoch 32/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.4431 - val_loss: 3.0061
# Epoch 33/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.4089 - val_loss: 2.7296
# Epoch 34/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.4262 - val_loss: 2.2261
# Epoch 35/50
# 52/52 [==============================] - 1s 19ms/step - loss: 2.4370 - val_loss: 2.2627
# Epoch 36/50
# 52/52 [==============================] - 1s 19ms/step - loss: 2.3533 - val_loss: 2.1659
# Epoch 37/50
# 52/52 [==============================] - 1s 19ms/step - loss: 2.1332 - val_loss: 2.1608
# Epoch 38/50
# 52/52 [==============================] - 1s 19ms/step - loss: 2.2759 - val_loss: 2.4239
# Epoch 39/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.2518 - val_loss: 2.0562
# Epoch 40/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.1166 - val_loss: 2.1903
# Epoch 41/50
# 52/52 [==============================] - 1s 19ms/step - loss: 1.9957 - val_loss: 2.0690
# Epoch 42/50
# 52/52 [==============================] - 1s 19ms/step - loss: 2.0515 - val_loss: 2.0397
# Epoch 43/50
# 52/52 [==============================] - 1s 19ms/step - loss: 1.9371 - val_loss: 2.1063
# Epoch 44/50
# 52/52 [==============================] - 1s 19ms/step - loss: 1.9173 - val_loss: 2.0050
# Epoch 45/50
# 52/52 [==============================] - 1s 18ms/step - loss: 2.0124 - val_loss: 2.0763
# Epoch 46/50
# 52/52 [==============================] - 1s 18ms/step - loss: 1.9199 - val_loss: 2.0807
# Epoch 47/50
# 52/52 [==============================] - 1s 19ms/step - loss: 1.9848 - val_loss: 2.2713
# Epoch 48/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.0068 - val_loss: 2.1527
# Epoch 49/50
# 52/52 [==============================] - 1s 19ms/step - loss: 1.9745 - val_loss: 1.9150
# Epoch 50/50
# 52/52 [==============================] - 1s 18ms/step - loss: 1.8495 - val_loss: 2.2495

# %%
plt.plot(history.history["loss"],label="loss")
plt.plot(history.history["val_loss"],label="val_loss")
plt.legend(loc="best")
plt.xlabel("No. Of Epochs")
plt.ylabel("mse score")
plt.show()

# %%
y_pred = model.predict(x_test)



from sklearn.metrics import mean_squared_error, r2_score
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print(rmse_lstm)


lower = y_pred - rmse_lstm
upper = y_pred + rmse_lstm
# Out:
# 1.5100548917441838

# %%
plt.figure(figsize=(16, 8))
plt.plot(y_test, label='true')
plt.plot(y_pred, label='predicted')
plt.fill_between(y_pred, lower, upper, alpha=0.2)
sns.despine()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5018/1506836301.py in <module>
#       2 plt.plot(y_test, label='true')
#       3 plt.plot(y_pred, label='predicted')
# ----> 4 plt.fill_between(y_pred, lower, upper, alpha=0.2)
#       5 sns.despine()
#       6 plt.show()
#
# ~/notebook/lib/python3.9/site-packages/matplotlib/pyplot.py in fill_between(x, y1, y2, where, interpolate, step, data, **kwargs)
#    2804         x, y1, y2=0, where=None, interpolate=False, step=None, *,
#    2805         data=None, **kwargs):
# -> 2806     return gca().fill_between(
#    2807         x, y1, y2=y2, where=where, interpolate=interpolate, step=step,
#    2808         **({"data": data} if data is not None else {}), **kwargs)
#
# ~/notebook/lib/python3.9/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1359     def inner(ax, *args, data=None, **kwargs):
#    1360         if data is None:
# -> 1361             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1362
#    1363         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/notebook/lib/python3.9/site-packages/matplotlib/axes/_axes.py in fill_between(self, x, y1, y2, where, interpolate, step, **kwargs)
#    5384     def fill_between(self, x, y1, y2=0, where=None, interpolate=False,
#    5385                      step=None, **kwargs):
# -> 5386         return self._fill_between_x_or_y(
#    5387             "x", x, y1, y2,
#    5388             where=where, interpolate=interpolate, step=step, **kwargs)
#
# ~/notebook/lib/python3.9/site-packages/matplotlib/axes/_axes.py in _fill_between_x_or_y(self, ind_dir, ind, dep1, dep2, where, interpolate, step, **kwargs)
#    5297                 (ind_dir, ind), (f"{dep_dir}1", dep1), (f"{dep_dir}2", dep2)]:
#    5298             if array.ndim > 1:
# -> 5299                 raise ValueError(f"{name!r} is not 1-dimensional")
#    5300
#    5301         if where is None:
#
# ValueError: 'x' is not 1-dimensional
