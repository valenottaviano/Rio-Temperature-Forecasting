# %%
import pandas as pd
import numpy as np
from numpy import array
from numpy import split
from sklearn.preprocessing import RobustScaler
import matplotlib.pyplot as plt
import seaborn as sns

# %%
raw_dataset = pd.read_csv('./station_rio.csv', index_col='YEAR')
raw_dataset.head()
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 1973  27.73  27.97  25.70  26.49  22.42  22.76  22.14  21.03  21.46  22.46
# 1974  26.68  27.16  26.56  23.94  22.76  20.70  21.20  21.81  22.91  22.80
# 1975  25.27  26.92  26.43  22.82  21.37  20.50  19.68  22.98  22.40  22.65
# 1976  27.48  26.20  25.55  24.99  22.01  21.18  20.14  21.15  21.27  22.06
# 1977  27.13  28.51  26.88  24.22  22.35  22.13  23.07  22.29  22.44  23.92
#
#         NOV    DEC  D-J-F  M-A-M  J-J-A  S-O-N  metANN
# YEAR
# 1973  23.06  25.85  27.45  24.87  21.98  22.33   24.16
# 1974  24.51  24.54  26.56  24.42  21.24  23.41   23.91
# 1975  24.11  26.53  25.58  23.54  21.05  23.05   23.31
# 1976  24.40  25.56  26.74  24.18  20.82  22.58   23.58
# 1977  24.48  24.84  27.07  24.48  22.50  23.61   24.42

# %%
raw_dataset.tail()
# Out:
#         JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# YEAR
# 2015  29.93  28.43  26.78  25.93  23.18  21.98  22.93  23.53  23.28  25.33
# 2016  27.08  28.98  27.43  27.93  22.93  20.53  21.53  23.23  23.03  24.48
# 2017  28.92  28.27  26.97  25.52  22.57  21.97  20.02  22.42  24.22  25.97
# 2018  28.06  27.21  27.81  26.26  23.81  22.91  22.96  21.91  23.71  24.56
# 2019  30.25  28.05  27.50  26.55  24.85  23.10  21.75  22.30  23.05  25.25
#
#          NOV     DEC  D-J-F  M-A-M  J-J-A  S-O-N  metANN
# YEAR
# 2015   26.43  999.90  28.91  25.30  22.81  25.01   25.51
# 2016   24.78   27.22  27.63  26.10  21.76  24.10   24.90
# 2017   25.47   27.01  28.14  25.02  21.47  25.22   24.96
# 2018   25.61   27.55  27.43  25.96  22.59  24.63   25.15
# 2019  999.90  999.90  28.62  26.30  22.38  24.74   25.51

# %% [markdown]
# ### Data preprocessing

# %%
def split_sequence (sequence, n_steps):
    X, y = list(), list()
    for i in range(len(sequence)):
        #find the end of the pattern
        end_ix = i + n_steps
        #check if we are beyond the sequence
        if end_ix > len(sequence)-1:
            break
        seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
        
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# %%
series = []

for year in range(len(raw_dataset.values)):
    for month in raw_dataset.values[year]:
        series.append(month)

# Handling wrong values
for i in range(len(series)):
    if series[i] > 60:
        num1 = 0
        num2 = 0
        
        k = 0
        while series[k] > 60:
            k = k+1
        num1 = series[k]
        
        k = 0
        while series[k] > 60:
            k = k-1
        num2 = series[k]
        
        series[i] = (num1 + num2)/2
        
series_arr = array(series)
X, y = split_sequence(series_arr, 12)
X = X.reshape((X.shape[0], X.shape[1], 1))
X.shape
print(X.shape, y.shape)
# Out:
# (787, 12, 1) (787,)

# %%
plt.figure(figsize=(20,5))
sns.lineplot([x for x in range(len(series))], series_arr)
plt.show()
# Out:
# /home/winston/notebook/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Bidirectional LSTM Model

# %%
x_train, y_train = X[:-12], y[:-12]
x_test, y_test = X[-12:], y[-12:]

# %%
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Dropout , LSTM , Bidirectional 

model = Sequential()
model.add(Bidirectional(LSTM(100,return_sequences=True,input_shape=(x_train.shape[1],x_train.shape[2]))))
model.add(Dropout(0.3))
model.add(Bidirectional(LSTM(100,input_shape=(x_train.shape[1],x_train.shape[2]))))
model.add(Dropout(0.2))
model.add(Dense(units=1))

model.compile(optimizer="adam",loss="mse")

history = model.fit(x_train, y_train, epochs=50, batch_size=12, validation_split=0.2, shuffle=True)
# Out:
# Epoch 1/50
# 52/52 [==============================] - 7s 33ms/step - loss: 109.9809 - val_loss: 5.9687
# Epoch 2/50
# 52/52 [==============================] - 1s 15ms/step - loss: 6.4222 - val_loss: 5.6497
# Epoch 3/50
# 52/52 [==============================] - 1s 15ms/step - loss: 6.5652 - val_loss: 5.7693
# Epoch 4/50
# 52/52 [==============================] - 1s 15ms/step - loss: 6.7759 - val_loss: 5.7445
# Epoch 5/50
# 52/52 [==============================] - 1s 15ms/step - loss: 6.2545 - val_loss: 5.6413
# Epoch 6/50
# 52/52 [==============================] - 1s 15ms/step - loss: 6.5519 - val_loss: 5.7607
# Epoch 7/50
# 52/52 [==============================] - 1s 16ms/step - loss: 6.3950 - val_loss: 5.7151
# Epoch 8/50
# 52/52 [==============================] - 1s 16ms/step - loss: 6.5014 - val_loss: 5.6450
# Epoch 9/50
# 52/52 [==============================] - 1s 17ms/step - loss: 6.5426 - val_loss: 6.0185
# Epoch 10/50
# 52/52 [==============================] - 1s 16ms/step - loss: 6.4480 - val_loss: 5.5861
# Epoch 11/50
# 52/52 [==============================] - 1s 16ms/step - loss: 6.3123 - val_loss: 5.5809
# Epoch 12/50
# 52/52 [==============================] - 1s 18ms/step - loss: 6.6593 - val_loss: 5.6532
# Epoch 13/50
# 52/52 [==============================] - 1s 16ms/step - loss: 6.7973 - val_loss: 5.8610
# Epoch 14/50
# 52/52 [==============================] - 1s 17ms/step - loss: 6.4335 - val_loss: 5.5595
# Epoch 15/50
# 52/52 [==============================] - 1s 17ms/step - loss: 6.4045 - val_loss: 5.7527
# Epoch 16/50
# 52/52 [==============================] - 1s 17ms/step - loss: 6.4876 - val_loss: 5.6424
# Epoch 17/50
# 52/52 [==============================] - 1s 17ms/step - loss: 5.7445 - val_loss: 4.6008
# Epoch 18/50
# 52/52 [==============================] - 1s 20ms/step - loss: 5.1551 - val_loss: 3.5177
# Epoch 19/50
# 52/52 [==============================] - 1s 21ms/step - loss: 4.1774 - val_loss: 2.7452
# Epoch 20/50
# 52/52 [==============================] - 1s 21ms/step - loss: 3.9993 - val_loss: 2.6164
# Epoch 21/50
# 52/52 [==============================] - 1s 20ms/step - loss: 3.6994 - val_loss: 2.4803
# Epoch 22/50
# 52/52 [==============================] - 1s 20ms/step - loss: 3.3186 - val_loss: 3.2079
# Epoch 23/50
# 52/52 [==============================] - 1s 20ms/step - loss: 3.5836 - val_loss: 2.5024
# Epoch 24/50
# 52/52 [==============================] - 1s 21ms/step - loss: 3.1388 - val_loss: 3.5752
# Epoch 25/50
# 52/52 [==============================] - 1s 21ms/step - loss: 3.5067 - val_loss: 2.5310
# Epoch 26/50
# 52/52 [==============================] - 1s 21ms/step - loss: 3.2173 - val_loss: 2.2546
# Epoch 27/50
# 52/52 [==============================] - 1s 20ms/step - loss: 3.0145 - val_loss: 2.3569
# Epoch 28/50
# 52/52 [==============================] - 1s 20ms/step - loss: 3.2428 - val_loss: 3.9225
# Epoch 29/50
# 52/52 [==============================] - 1s 23ms/step - loss: 3.6042 - val_loss: 2.4951
# Epoch 30/50
# 52/52 [==============================] - 1s 22ms/step - loss: 3.3278 - val_loss: 2.1284
# Epoch 31/50
# 52/52 [==============================] - 1s 20ms/step - loss: 3.4173 - val_loss: 2.1845
# Epoch 32/50
# 52/52 [==============================] - 1s 23ms/step - loss: 2.9185 - val_loss: 3.0634
# Epoch 33/50
# 52/52 [==============================] - 1s 20ms/step - loss: 3.0102 - val_loss: 2.3252
# Epoch 34/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.9670 - val_loss: 1.9578
# Epoch 35/50
# 52/52 [==============================] - 1s 19ms/step - loss: 2.8317 - val_loss: 2.9087
# Epoch 36/50
# 52/52 [==============================] - 1s 21ms/step - loss: 3.1074 - val_loss: 2.3186
# Epoch 37/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.7510 - val_loss: 2.2314
# Epoch 38/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.9532 - val_loss: 2.2356
# Epoch 39/50
# 52/52 [==============================] - 1s 21ms/step - loss: 2.8628 - val_loss: 2.1029
# Epoch 40/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.9094 - val_loss: 2.1435
# Epoch 41/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.9735 - val_loss: 2.3121
# Epoch 42/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.6534 - val_loss: 2.1821
# Epoch 43/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.6738 - val_loss: 2.2496
# Epoch 44/50
# 52/52 [==============================] - 1s 21ms/step - loss: 2.7355 - val_loss: 2.2421
# Epoch 45/50
# 52/52 [==============================] - 1s 20ms/step - loss: 2.8115 - val_loss: 1.8290
# Epoch 46/50
# 52/52 [==============================] - 1s 21ms/step - loss: 2.6275 - val_loss: 2.2727
# Epoch 47/50
# 52/52 [==============================] - 1s 19ms/step - loss: 2.8741 - val_loss: 2.0439
# Epoch 48/50
# 52/52 [==============================] - 1s 19ms/step - loss: 2.6598 - val_loss: 1.6691
# Epoch 49/50
# 52/52 [==============================] - 1s 19ms/step - loss: 2.8884 - val_loss: 2.7949
# Epoch 50/50
# 52/52 [==============================] - 1s 19ms/step - loss: 3.0749 - val_loss: 2.3027

# %%
plt.plot(history.history["loss"],label="loss")
plt.plot(history.history["val_loss"],label="val_loss")
plt.legend(loc="best")
plt.xlabel("No. Of Epochs")
plt.ylabel("mse score")
plt.show()

# %%
y_pred = model.predict(x_test)



from sklearn.metrics import mean_squared_error, r2_score
rmse_lstm = np.sqrt(mean_squared_error(y_test, y_pred))
print(rmse_lstm)


lower = y_pred - rmse_lstm
upper = y_pred + rmse_lstm
# Out:
# 1.7075034767626631

# %%
plt.figure(figsize=(16, 8))
plt.plot(y_test, label='true')
plt.plot(y_pred, label='predicted')
sns.despine()
plt.show()
